# %%
import sys

import numpy as np
import pandas as pd
import functions as DLmodels          

# dados_polarity = pd.read_csv('../logs/data-polarity.csv')
dados_mape_self = pd.read_csv('../logs/data_MAPE_self.csv')
dados_mape_self['Type'] = 'dados_mape_self'

dados_mape_self_complete = pd.read_csv('../logs/data_MAPE_self_complete.csv')
dados_mape_self_complete['Type'] = 'dados_mape_self_complete'

dados_mape_mix = pd.read_csv('../logs/data_MAPE_mix.csv')
dados_mape_mix['Type'] = 'dados_mape_mix'

dados_future_self = pd.read_csv('../logs/data_future_self.csv')
dados_future_self['Type'] = 'dados_future_self'
dados_future_self['MAPE'] = dados_future_self['gain_pred']


dados_future_self_complete = pd.read_csv('../logs/data_future_self_complete.csv')
dados_future_self_complete['Type'] = 'dados_future_self_complete'
dados_future_self_complete['MAPE'] = dados_future_self_complete['gain_pred']

dados_future_mix = pd.read_csv('../logs/data_future_mix.csv')
dados_future_mix['Type'] = 'dados_future_mix'
dados_future_mix['MAPE'] = dados_future_self['gain_pred']

# %%
dados_mape_self = dados_mape_self[['Stock',	'ML',	'MAPE', 'Type']]      
dados_mape_mix = dados_mape_mix[['Stock',	'ML',	'MAPE', 'Type']]      
dados_mape_self_complete= dados_mape_self_complete[['Stock',	'ML',	'MAPE', 'Type']]      



data_mape = pd.concat([dados_mape_self,
           dados_mape_mix,
           dados_mape_self_complete
          ])
data_mape = data_mape[(data_mape['MAPE'] < 5)]


dados_future_self = dados_future_self[['Stock',	'ML',	'MAPE', 'Type']]      
dados_future_mix = dados_future_mix[['Stock',	'ML',	'MAPE', 'Type']]      
dados_future_self_complete= dados_future_self_complete[['Stock',	'ML',	'MAPE', 'Type']]      



data_future = pd.concat([
           dados_future_self,
           dados_future_mix,
           dados_future_self_complete
          ])


data_mape['ML'].unique()
data = pd.concat([data_mape, data_future[data_future['Stock'].isin(data_mape['ML'].unique())]])
data
# Out:
#      Stock                 ML  MAPE                      Type
# 0    ABCB4               LSTM   2.3           dados_mape_self
# 14   AGRO3         convLSTM1D   2.9           dados_mape_self
# 17   ALPA3  BidirectionalLSTM   2.4           dados_mape_self
# 18   ALPA3         convLSTM1D   3.3           dados_mape_self
# 37   B3SA3  BidirectionalLSTM   4.7           dados_mape_self
# ..     ...                ...   ...                       ...
# 525  VULC3  BidirectionalLSTM   1.8  dados_mape_self_complete
# 526  VULC3         convLSTM1D   1.9  dados_mape_self_complete
# 530  VVAR3         convLSTM1D   2.9  dados_mape_self_complete
# 540  YDUQ3               LSTM   3.1  dados_mape_self_complete
# 542  YDUQ3         convLSTM1D   2.9  dados_mape_self_complete
#
# [251 rows x 4 columns]

# %%
# dados['Gain'].loc[dados['Gain'] > 10] = 10
# dados = dados.loc[(dados['Gain'] > 0) & (dados['TSA'] > 0)]
filenamePlot = 'all_data_less5'
plot_size = 20
var_plot_bar_all_predictions = DLmodels.plot_bar_predictions(data, filenamePlot, 'ML', 'MAPE', 'Stock',plot_size)
# Out:
# /home/marcos/tf-cpu/lib/python3.8/site-packages/plotnine/ggplot.py:727: PlotnineWarning: Saving 20 x 20 in image.
# /home/marcos/tf-cpu/lib/python3.8/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: images/plot_Bar_all_data_less5.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-ef1d3c1d2143> in <module>
#       3 filenamePlot = 'all_data_less5'
#       4 plot_size = 20
# ----> 5 var_plot_bar_all_predictions = DLmodels.plot_bar_predictions(data, filenamePlot, 'ML', 'MAPE', 'Stock',plot_size)
#
# ~/GIT/OracleStock/src/functions.py in plot_bar_predictions(data, filenamePlot, x, y, facet, plot_size)
#     289       p9.theme(subplots_adjust={'wspace': 0.25})
#     290
# --> 291     p9.ggsave(var_plot_bar_all_predictions, 'images/plot_Bar_' + filenamePlot + '.png',height=plot_size, width=plot_size, units = 'in', dpi=300)
# ...
